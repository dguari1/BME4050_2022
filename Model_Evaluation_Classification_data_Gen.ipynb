# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.datasets import make_regression, make_classification
from sklearn.linear_model import SGDRegressor, SGDClassifier
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
## generate data
X,y = make_classification(n_samples = 1000, n_features = 2, n_informative = 2, n_redundant=0)
plt.figure(figsize=(10, 4))
plt.plot(X[y==0, 0], X[y==0, 1], "bs")
plt.plot(X[y==1, 0], X[y==1, 1], "g^")
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show();

# %%
data = pd.DataFrame(columns = ['x1','x2','target'], data = np.column_stack((X,y)))
data.to_csv('Example_classification.csv')

# %%
data
# Out:
#            x1        x2  target
# 0    0.306628  0.499506     1.0
# 1    1.170077  0.366337     1.0
# 2   -1.520936 -0.868998     0.0
# 3   -0.857305  1.895029     0.0
# 4   -1.236183 -1.593495     0.0
# ..        ...       ...     ...
# 995 -1.241224 -1.848086     0.0
# 996  2.573076 -2.948846     1.0
# 997 -0.969862  0.340523     0.0
# 998 -1.074030  1.826500     0.0
# 999 -0.800780  1.426315     0.0
#
# [1000 rows x 3 columns]
